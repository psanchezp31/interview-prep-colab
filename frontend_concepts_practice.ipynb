# %% [markdown]
# <a href="https://colab.research.google.com/github/psanchezp31/interview-prep-colab/blob/main/frontend_concepts_practice.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # JAVASCRIPT

# %% [markdown]
# ## OBJECT REFERENCE

# %% [markdown]
# object reference: a) After assigning a to b both constants contain a reference to the same object,
#  thus changes made through either of them affect the same object, and logging them prints the same value;

# %%
# %%js
# const a = [15];
# const b = a;
# b.push(2);
# console.log(a,b)

# %% [markdown]
# Although we declared b as a constant, you can still make changes on it,
# as it is just holding object reference value, and this something you can not change,
# meaning that you can not reassign another object to constant.

# %%
const c = "hola"
b = c  #I can't do this. I can't reassing another object to constant

# %% [markdown]
# ## HOISTING

# %% [markdown]
# the interpreter appears to move the **declaration of functions, variables or classes** to the top of their scope, prior to execution of the code. This happens in the creation phase of the Execution Context.

# %% [markdown]
# ### Function hoisting

# %% [markdown]
# #### With function declaration

# %% [markdown]
# Functions, when declared with a **function declaration**, are always hoisted to the top of the current scope

# %%
# %%js
# catName("Tiger");  //Call a function before it has been declared
#
# function catName(name) {
#   console.log("My cat's name is " + name);
# }

# %% [markdown]
# #### With function expression

# %% [markdown]
# When declared with a **function expression**, functions are not hoisted to the top of the current scope.

# %%
# %%js
# sayHello() // Error, sayHello is not defined
# const sayHello = function () {  //function expression
#   console.log(aFunction)
# }

# %% [markdown]
# ## VAR

# %% [markdown]
# ### var scope
#   globally scoped (outside a function) or function/locally scoped (inside a function)

# %%
# %%js
# var tester = "hey hi";
#
# function newFunction() {
#     var hello = "hello";
# }
# console.log(hello); // error: hello is not defined

# %% [markdown]
# Can be redeclared and updated

# %%
# %%js
# var greeter = "hey hi";
# var greeter = "say Hello instead";
# var greeter = "hey hi";
#     greeter = "say Hello instead";
# console.log(greeter)

# %% [markdown]
# ### hoisting of var

# %% [markdown]
# variables and function declarations are moved to the top of their scope before code execution.

# %%
 # %%js
 var greeter;
 console.log(greeter); // greeter is undefined
 greeter = "say hello"

# %% [markdown]
# So var variables are hoisted to the top of their scope and initialized with a value of undefined

# %% [markdown]
# ### problem with var

# %%
    # %%js
    var greeter = "hey hi";
    var times = 4;

    if (times > 3) {
        var greeter = "say Hello instead";
    }

    console.log(greeter) // "say Hello instead" - It has already been defined before. It will change in other parts of the code

# %% [markdown]
# ## LET

# %% [markdown]
# ### let scope

# %% [markdown]
# It is only avaible to use within a block {}

# %%
# %%js
#   let greeting ="say hi";
#   let times = 4;
#
# if(times > 3){
#   let hello = "say hello instead";
#   console.log(hello) //"say hello instead"
# }
# console.log(hello) //hello is not defined

# %% [markdown]
# can be updated but no re-declared

# %%
# %%js
#     let greeting = "say Hi";
#     greeting = "say Hello instead"; //updating
#     console.log(greeting)

# %%
    # %%js
    let greeting = "say Hi";
    let greeting = "say Hello instead"; // error: Identifier 'greeting' has already been declared

# %% [markdown]
# However, if the same variable is defined in different scopes, there will be no error:

# %%
 # %%js
 let greeting = "say Hi";
    if (true) {
        let greeting = "say Hello instead";
        console.log(greeting); // "say Hello instead"
    }
    console.log(greeting); // "say Hi"

# %% [markdown]
# ### hoisting of let

# %% [markdown]
# let declarations are hoisted to the top. Let keyword are not initilized as undefined like var. If you try to use a let variable before declaration you'll get a Reference Error

# %%
# %%js
# if (true) {
#         console.log(greeting); // "ReferenceError"
#     }
#         let greeting = "say Hello instead";

# %% [markdown]
# ##CONST

# %% [markdown]
# Maintein constant values. Share some similarities with let:
# - Are block scoped

# %% [markdown]
# ### hoisting of const

# %% [markdown]
# declarations are hoisted to the top but are not initialized

# %% [markdown]
# ## SIMILARILITES LET AND CONST

# %% [markdown]
# *   Accessing the variable before the declaration results in a ReferenceError.

# %%
# %%js
# console.log(hola)  //ReferenceError can't access lexical declaration 'hola' before initialization
# let hola;

# %% [markdown]
# ## DIFFERENCES BETWEEN LET AND CONST

# %% [markdown]
# *   const cannot be updated or re-declared

# %%
# %%js
# const greeting = "say Hi";
# greeting = "say Hello instead";// error: Assignment to constant variable.
#
# const greeting = "say Hi";
# const greeting = "say Hello instead";// error: Identifier 'greeting' has already been declared

# %% [markdown]
#
#
# *    let: If no initial value is specified on declaration, the variable is initialized with a value of undefined.

# %%
# %%js
# let hola; // declaration
# console.log(hola)  //undefined, because it hasn't an initial value

# %% [markdown]
# *   const: It has to be initialized at the time it's declaration

# %%
# %%js
# const hola; //SyntaxError: missing = in const declaration

# %% [markdown]
# ## FUNCTIONS

# %% [markdown]
# In JavaScript, functions are first-class objects, because they can have properties and methods just like any other object. What distinguishes them from other objects is that functions can be called. In brief, they are Function objects

# %% [markdown]
# ## CLASSES

# %% [markdown]
# CLASSES = "SPECIAL FUNCTIONS", you can define **FUNCTION EXPRESSIONS OR FUNCTIONS DECLARATIONS**

# %% [markdown]
# ### Class declarations

# %%
# %%js
# class Rectangle {  //use class keyword
#     constructor(height, width){
#       this.height = height;
#       this.width = width
#     }
# }

# %% [markdown]
# ### Class expressions

# %% [markdown]
# can be named or unnamed. The name given to a named class expression is local to the class's body. However, it can be accessed via the name property.

# %%
# %%js
# // unnamed
# let Rectangle = class {
#   constructor(height, width) {
#     this.height = height;
#     this.width = width;
#   }
# };
# console.log(Rectangle.name);
# // output: "Rectangle"
#
# // named
# let Rectangle = class Rectangle2 {
#   constructor(height, width) {
#     this.height = height;
#     this.width = width;
#   }
# };
# console.log(Rectangle.name);
# // output: "Rectangle2"

# %% [markdown]
# ## JS TYPES

# %% [markdown]
# The set of types in the JavaScript language consists of primitive values and objects.
#
# * Primitive values (immutable datum represented directly at the lowest level of the language)
#    *  Boolean type
#    *  Null type
#    * Undefined type
#    * Number type
#    * BigInt type
#    * String type
#    * Symbol type
# * Objects (collections of properties)

# %% [markdown]
# ### Primitive values

# %% [markdown]
# All primitives are immutable, i.e., they cannot be altered.
# The variable may be reassigned a new value, but the existing value can not be changed in the ways that objects, arrays, and functions can be altered.

# %%
# %%js
# // Using a string method doesn't mutate the string
# var bar = "baz";
# console.log(bar);               // baz
# bar.toUpperCase();
# console.log(bar);               // baz
# // Assignment gives the primitive a new (not a mutated) value
# bar = bar.toUpperCase();       // BAZ

# %% [markdown]
# ##CONTEXT IN JAVASCRIPT

# %% [markdown]
# In JavaScript, “context” refers to an object. Within an object, the keyword “this” refers to that object (i.e. “self”), and provides an interface to the properties and methods that are members of that object.

# %% [markdown]
# ### this in the Global Context

# %% [markdown]
# In the GEC (outside of any function and object), this refers to the global object — which is the window object

# %% [markdown]
# Functions and variables in the GEC get attached as methods and properties to the `window` object.
# the `window` object only exist in browser, in node.js the correct is `global`

# %%
# %%js
# var occupation = "Frontend Developer";
#
# function addOne(x) {
#     console.log(x + 1)
# }
#
# //this is the same:
#
# window.occupation = "Frontend Developer";
# window.addOne = (x) => {
# console.log(x + 1)
# };

# %% [markdown]
# ### this in Functions declared in the GEC

# %% [markdown]
# In the case of the FEC, it doesn't create the this object. Rather, it get's access to that of **the environment it is defined in.**
#
# Here that'll be the window object, as the function is defined in the GEC:

# %%
# %%js
# var msg = "I will rule the world!";
#
# function printMsg() { //Function gets access of the environment is defined in, in this case GLOBAL CONTEXT - WINDOW
#     console.log(this); //Is the Window object
#     console.log(this.msg)
# }
#
# printMsg(); // logs "I will rule the world!" to the console.

# %% [markdown]
# ### this in functions declared inside Objects

# %% [markdown]
# In objects, the this keyword doesn't point to the GEC, but to the object itself.

# %%
# %%js
# var msg = "I will rule the world!";
# const Victor = {
#     msg: "Victor will rule the world!",
#     printMsg() {
#       console.log(this)
#       console.log(this.msg)
#       },  // this has the context of the object itself, not the global or GEC
# };
#
# Victor.printMsg(); // logs "Victor will rule the world!" to the console.

# %% [markdown]
# ### this exercise

# %%
# %%js
# const obj = {
#   a: this,
#   b: function(){
#     return this;
#   },
#   c: ()=>{
#     return this;
#   },
#   d(){
#     return this;
#   },
#   e: function(){
#     return this.a;
#   }
# }
# console.log(obj.a) // obj is declared in the GEC, due to that this points to de Window - Global Execution Context
# console.log(obj.b) // This function is declared inside an object, this points to the object itself
# console.log(obj.c) // This function is declared inside an object, this points to the object itself
# console.log(obj.d) // This function is declared inside an object, this points to the object itself
# console.log(obj.e) // This function is declared inside an object, this points to the object itself
# console.log(this)

# %%
# %%js
# const obj = {a: this}
# function whatsThis(){
#   return obj.a
# }
# console.log(whatsThis())

# %% [markdown]
# ## SCOPE

# %% [markdown]
# A scope in JavaScript defines what variables you have access to.
# There are two kinds of scope – **global scope and local scope.**

# %% [markdown]
# ### Global Scope

# %% [markdown]
# If a variable is declared outside all functions or curly braces ({}), it is said to be defined in the global scope.

# %% [markdown]
# ### Local Scope

# %% [markdown]
# Variables that are usable only in a specific part of your code are considered to be in a local scope. These variables are also called local variables.
#
# **In JavaScript, there are two kinds of local scope: function scope and block scope.**

# %% [markdown]
# #### Function scope

# %% [markdown]
# When you declare a variable in a function, you can access this variable only within the function. You can’t get this variable once you get out of it.

# %%
# %%js
# function sayHello () {
#   const hello = 'Hello CSS-Tricks Reader!'
#   console.log(hello)
# }
#
# sayHello() // 'Hello CSS-Tricks Reader!'
# console.log(hello) // Error, hello is not defined

# %% [markdown]
# #### Block scope

# %% [markdown]
# When you declare a variable with const or let within a curly brace ({}), you can access this variable only within that curly brace.

# %%
# %%js
# {
#   const hello = 'Hello CSS-Tricks Reader!'
#   console.log(hello) // 'Hello CSS-Tricks Reader!'
# }
#
# console.log(hello) // Error, hello is not defined

# %% [markdown]
# ## DIFFERENCES BETWEEN SCOPE AND CONTEXT

# %% [markdown]
# Scope pertains to the visibility of variables, and context refers to the object to which a function belongs.
# Fundamentally, scope is function-based while context is object-based. In other words, scope pertains to the variable access of a function when it is invoked and is unique to each invocation. Context is always the value of the this keyword, which is a reference to the object that “owns” the currently executing code.

# %% [markdown]
# ##LEXICAL SCOPE

# %% [markdown]
# Lexical scope is the definition area of an expression.
#
# In other words, an item's lexical scope is the place in which the item got created.
#
# Note:
#
# * Another name for lexical scope is static scope.
# * The place an item got invoked (or called) is not necessarily the item's lexical scope. Instead, an item's definition space is its lexical scope.

# %% [markdown]
# ##LEXICAL ENVIRONMENTS

# %% [markdown]
# scopes are “implemented” via lexical environments. They consist of two components:
#
#
# *  An environment record that maps variable names to variable values (think dictionary). This is the actual storage space for the variables of the scope. The name-value entries in the record are called bindings.
#
# * A reference to the outer environment – the environment for the outer scope.

# %% [markdown]
# ##CLOSURES

# %% [markdown]
# Whenever you create a function within another function, you have created a closure. The inner function is the closure. This closure is usually returned so you can use the outer function’s variables at a later time.
# Since closures have access to the variables in the outer function, they are usually used for two things:
#
# * To control side effects
# * To create private variables

# %%
# %%js
# function outerFunction () {
#   const outer = `I see the outer variable!`
#
#   return function innerFunction() {
#     console.log(outer)
#   }
# }
#
# outerFunction()() // I see the outer variable!

# %% [markdown]
# ## CONTEXT VS. EXECUTION CONTEXT

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# * CONTEXT: Is related to the value of "this" keyword, the object that is executing a function in a specific moment.
#
# * EXECUTION CONTEXT: Is related to the call stack:
#
#   * Every time that JS executes a function, creates an execution context to that function, loading to the memory everything needed to execute it: params, name of the file that the function belongs, number of the next execution line, also creates a new scope or lexical environment for the variables declared in the function, lastly determine the value of this for this function(context).
#   * JS execute all of the above every time that executes a function.
#   * https://www.youtube.com/watch?v=bS71_W_BDFE 3:00

# %% [markdown]
# ## HOW JAVASCRIPT CODE GETS EXECUTED

# %% [markdown]
# 1.   While reading through HTML, if the browser encounters JavaScript code to run via a `<script>` tag, it sends it to its JavaScript engine.
# 2.   The browser's JavaScript engine then creates a special environment to handle the transformation and execution of this JavaScript code. This environment is known as the Execution Context.
# 3. During the Execution Context run-time, the specific code gets parsed by a parser
# 4. There are two kinds of Execution Context in JavaScript:
#
#
#
# *   Global Execution Context (GEC)
# *   Function Execution Context (FEC)

# %% [markdown]
# ### Global Execution Context

# %% [markdown]
# The GEC is the base/default Execution Context where all JavaScript code that is not inside of a function gets executed.
#
# For every JavaScript file, there can only be one GEC.

# %% [markdown]
# ### Function Execution Context

# %% [markdown]
# Whenever a function is called, the JavaScript engine creates a different type of Execution Context known as a Function Execution Context (FEC) within the GEC to evaluate and execute the code within that function.
#
# Since every function call gets its own FEC, there can be more than one FEC in the run-time of a script.

# %% [markdown]
# ### How are Execution Context created?

# %% [markdown]
# The creation of an Execution Context (GEC or FEC) happens in two phases:
#
#     * Creation Phase
#     * Execution Phase

# %% [markdown]
# #### Creation phase or Compilation

# %% [markdown]
# 1.   Creates the Variable Object (VO) -> Store variables and function declarations in memory prior to execution of the code (Hoisting)
# 2.   Creates the Scope Chain
#     * This idea of the JavaScript engine traversing up the scopes of the execution contexts that a function is defined in in order to resolve variables and functions invoked in them is called the scope chain
#
#
# ![image.png](data:image/png;base64,...)

# %%
# %%js
# var a =  "Hey";
# console.log(c) // I can't access c because is inside another function - this is the scope chain
# first();
# function first(){
#   var b = "Hello";
#   second();
#   function second(params){
#     var c = "Hi";
#     console.log(a+b+c)
#   }
# }

# %% [markdown]
# However, this doesn't work backward. That is, the global scope will never have access to the inner function’s variables unless they are returned from the function.
#
# The scope chain works as a one-way glass. You can see the outside, but people from the outside cannot see you.

# %% [markdown]
# 3.  The value of "this" keyword ->  The JavaScript this keyword refers to the scope where an Execution Context belongs.
#
# Once the scope chain is created, the value of 'this' is initialized by the JS engine.

# %% [markdown]
# #### Execution phase

# %% [markdown]
# The JavaScript engine reads the code in the current Execution Context once more, then updates the VO with the actual values of these variables. Then the code is parsed by a parser, gets transpired to executable byte code, and finally gets executed.

# %% [markdown]
# ## CALL STACK

# %% [markdown]
# A call stack is a mechanism for an interpreter (like the JavaScript interpreter in a web browser) to keep track of its place in a script that calls multiple functions — what function is currently being run and what functions are called from within that function, etc.
#
# * When a script calls a function, the interpreter adds it to the call stack and then starts carrying out the function.
# * Any functions that are called by that function are added to the call stack further up, and run where their calls are reached.
# * When the current function is finished, the interpreter takes it off the stack and resumes execution where it left off in the last code listing.
# * If the stack takes up more space than it had assigned to it, it results in a "stack overflow" error.
# * uses the LIFO paradigm (Last In First Out)

# %% [markdown]
# ##EVENT LOOP

# %% [markdown]
# The event loop constantly checks whether or not the call stack is empty. If it is empty, new functions are added from the event queue. If it is not, then the current function call is processed

# %% [markdown]
# ##TASK QUEUE OR EVENT QUEUE OR QUEUE

# %% [markdown]
# The event queue is responsible for sending new functions to the stack for processing. It follows the queue data structure to maintain the correct sequence in which all operations should be sent for execution.

# %% [markdown]
# ##MICROTASK QUEUE

# %% [markdown]
# If we have a **promise or async functions** in our code, this promise is going to be handle in a different way. Promises callbacks are going to the microtask queue and not to the task queue. Promises callbacks in the microtask queue **has a major precedence** than task in the task queue or the macrotask, so the event loop will pass first the microtask present in that queue.
# * https://www.youtube.com/watch?v=hIFkCrkkHMg

# %% [markdown]
# ##MACROTASK QUEUE

# %% [markdown]
# Macrotask queue it's like a living room that stack all the callback from **setTimeout, setInterval, setImmediate, UI rendering that comes from web APIs**.
#
# * https://www.youtube.com/watch?v=CY9DHw1wpTM&t=253s

# %% [markdown]
# ## MEMORY HEAP VS. STACK

# %% [markdown]
# * MEMORY HEAP: The heap is a different space for storing data where JavaScript stores **objects and functions.**
# Allocating memory this way is also called dynamic memory allocation.
#
# * STACK MEMORY: Static data is data where the engine knows the size at compile time. In JavaScript, this includes
#
# **primitive values** (strings, numbers, booleans, undefined, and null) and **references**, which point to objects and functions.

# %% [markdown]
# ## WEB APIs

# %% [markdown]
# All browsers have a set of built-in Web APIs to support complex operations, and to help accessing data, examples:
# * ConsoleAPI
# * DOM
# * Fetch API
# * URL API
# * Web Storage API
# * Web workers API
# * setTimeout

# %% [markdown]
# ## KEYED COLLECTIONS

# %% [markdown]
# ## DIFFERECES BETWEEN ARRAY AND SET

# %% [markdown]
# The biggest difference between an Array & Set is that Arrays can have duplicate values whereas Sets cannot. The other big difference is that data in an array is ordered by index whereas Sets use keys & the elements are iterable in the order of insertion

# %% [markdown]
# ### Set

# %% [markdown]
# Set objects are collections of values.
# * **Constructor:** Set()
# * **Instance properties:** Set.prototype.size
# * **Instance methods:**
#   * Set.prototype.add(value)
#   * Set.prototype.clear()
#   * Set.prototype.delete(value)
#   * Set.prototype.has(value)
# * **Iteration methods:**
#   * Set.prototype.values()
#   * Set.prototype.keys()
#   * Set.prototype.entries()
#   * Set.prototype.forEach(callbackFn[, thisArg])

# %%
# %%js
# const mySet1 = new Set()
#
# mySet1.add(1)           // Set [ 1 ]
# mySet1.add(5)           // Set [ 1, 5 ]
# mySet1.add(5)           // Set [ 1, 5 ]
# mySet1.add('some text') // Set [ 1, 5, 'some text' ]
# const o = {a: 1, b: 2}
# mySet1.add(o)
#
# mySet1.add({a: 1, b: 2})   // o is referencing a different object, so this is okay
#
# mySet1.has(1)              // true
# mySet1.has(3)              // false, since 3 has not been added to the set
# mySet1.has(5)              // true
# mySet1.has(Math.sqrt(25))  // true
# mySet1.has('Some Text'.toLowerCase()) // true
# mySet1.has(o)       // true
#
# mySet1.size         // 5
#
# mySet1.delete(5)    // removes 5 from the set
# mySet1.has(5)       // false, 5 has been removed
#
# mySet1.size         // 4, since we just removed one value
#
# console.log(mySet1)
# // logs Set(4) [ 1, "some text", {…}, {…} ] in Firefox
# // logs Set(4) { 1, "some text", {…}, {…} } in Chrome
#
# // converting between Set and Array
# const mySet2 = new Set([1, 2, 3, 3, 4])  //it delete the duplicated 3
# console.log(mySet2)
# for (let [key, value] of mySet1.entries()) console.log(key)
# console.log(typeof mySet1) //object

# %% [markdown]
# ### Map

# %% [markdown]
# The Map object holds key-value pairs and remembers the original insertion order of the keys. Any value (both objects and primitive values) may be used as either a key or a value.

# %% [markdown]
# * **Constructor:** Map()
# * **Instance properties:** Map.prototype.size
# * **Instance methods:**
#   * Map.prototype.clear()
#   * Map.prototype.delete(key)
#   * Map.prototype.has(key)
#   * Map.prototype.get(key)
#   * Map.prototype.set(key,value)
# * **Iteration methods:**
#   * Map.prototype.values()
#   * Map.prototype.keys()
#   * Map.prototype.entries()
#   * Map.prototype.forEach(callbackFn[, thisArg])

# %%
# %%js
# const myMap = new Map()
#
# const keyString = 'a string'
# const keyObj    = {}
# const keyFunc   = function() {}
#
# // setting the values
# myMap.set(keyString, "value associated with 'a string'")
# myMap.set(keyObj, 'value associated with keyObj')
# myMap.set(keyFunc, 'value associated with keyFunc')
#
# myMap.size              // 3
#
# // getting the values
# myMap.get(keyString)    // "value associated with 'a string'"
# myMap.get(keyObj)       // "value associated with keyObj"
# myMap.get(keyFunc)      // "value associated with keyFunc"
#
# myMap.get('a string')    // "value associated with 'a string'"
#                          // because keyString === 'a string'
# myMap.get({})            // undefined, because keyObj !== {}
# myMap.get(function() {}) // undefined, because keyFunc !== function () {}
# console.log(typeof myMap) //object

# %% [markdown]
# ### Objects vs.Maps

# %% [markdown]
# * A map does not cointain any keys by default. Objects has a prototype, so it cointains default keys.
# * A Map's keys can be any value(including functions, objects, or any primitive), key Objects must be either a String or a Symbol
# * The number of items in a Map can be retrieved from its size property. In Objects it can be with Object.keys().length
# * A Map is an iterable, an Object not. (Iterable objects are objects that can be iterated over with for..of.)
# * Map Performs better in scenarios involving frequent additions and removals of key-value pairs, Objects are no optimized for the same.

# %% [markdown]
# ### VALUE TYPES AND REFERENCES TYPES

# %% [markdown]
# JavaScript has 5 data types that are copied by **value**: Boolean, null, undefined, String, and Number. We’ll call these primitive types.
#
# JavaScript has 3 data types that are copied by having their **reference** copied: Array, Function, and Object. These are all technically Objects, so we’ll refer to them collectively as Objects.

# %% [markdown]
# ### Primitives

# %% [markdown]
# When we assign these variables to other variables using =, we copy the value to the new variable. **They are copied by value.**

# %%
# %%js
# const x = 10;
# const y = 'abc';
#
# const a = x;
# const b = y;
#
# console.log(x, y, a, b);
# // -> 10, 'abc', 10, 'abc'

# %% [markdown]
# ### Objects

# %% [markdown]
# Variables that are assigned a non-primitive value are given a reference to that value. **That reference points to the object’s location in memory. The variables don’t actually contain the value.**

# %% [markdown]
# When we use arr to do something, such as pushing a value, the JavaScript engine goes to the location of arr in memory and works with the information stored there.

# %% [markdown]
# #### Assigning by reference

# %%
# %%js
# const reference = [1] //array
# const refCopy = reference; // we are copying the reference, the address of the original object "reference"

# %% [markdown]
#  if we alter reference, refCopy will see those changes

# %%
# %%js
# reference.push(2);
# console.log(reference, refCopy);  // both changes because they all point to the same reference in memory
# // -> [1, 2], [1, 2]

# %% [markdown]
# #### Reassigning a Reference

# %%
# %%js
# let obj = { first: 'reference' };
# obj = { second: 'ref2' } // The address stored in obj changes. The first object is still present in memory,

# %% [markdown]
# When there are no references to an object remaining, the JavaScript engine can perform **garbage collection**. In this case, the object { first: 'reference' } is no longer accessible through any variables and is available to the engine for garbage collection.

# %% [markdown]
# #### == and === equality operators

# %% [markdown]
# on reference-type variables, they check the reference. If the variables contain a reference to the same item, the comparison will result in true

# %% [markdown]
# The strict equality operator (===) checks whether its two operands are equal, returning a Boolean result. Unlike the equality operator (==), the strict equality operator always considers operands of different types to be different.

# %%
# %%js
# const arrRef = ['Hi!'];
# const arrRef2 = arrRef;
#
# console.log(arrRef === arrRef2); // -> true because they check the REFERENCE
# console.log(arrRef == arrRef2); // -> true
#
# //
#
# const arr1 = ['Hi!']; //they contain the same
# const arr2 = ['Hi!'];
#
# console.log(arr1 === arr2); // -> but it's FALSE because it is not the same REFERENCE
# console.log(arr1 == arr2); // -> false

# %% [markdown]
# #### Comparing objects

# %% [markdown]
# we need to write a function that checks each property in both objects and makes sure they are the same. Shallow equality algorithm, and Deep equality algorithm. Because using ==, ===, or Object.is() will result bad.

# %% [markdown]
# #### Pure functions

# %% [markdown]
# As long as a **function only takes primitive values as parameters** and doesn’t use any variables in its surrounding scope, it is automatically pure, as it can’t affect anything in the outside scope

# %% [markdown]
# A function that takes in an **Object**, however, **can mutate the state of its surrounding scope**. If a function takes in an array reference and alters the array that it points to

# %%
# %%js
# function changeAgeImpure(person) { //impure function
#     person.age = 25; //changes Alex object
#     return person; // return the same object because person parameter is passed by reference
# }
#
# const alex = {
#     name: 'Alex',
#     age: 30
# };
#
# const changedAlex = changeAgeImpure(alex);
#
# console.log(alex); // -> { name: 'Alex', age: 25 }
# console.log(changedAlex); // -> { name: 'Alex', age: 25 }
# console.log(alex === changedAlex); // -> true  //because points to the same object in memory

# %%
# %%js
# function changeAgePure(person) {  //pure function
#     const {...newPersonObj} = person;  // person is isolated by creating a new variable newPersonObj
#     newPersonObj.age = 25;
#     return newPersonObj;
# }
#
# const alex = {
#     name: 'Alex',
#     age: 30
# };
#
# const alexChanged = changeAgePure(alex);
#
# console.log(alex); // -> { name: 'Alex', age: 30 }  //doesn't change
# console.log(alexChanged); // -> { name: 'Alex', age: 25 }  // is the newPersonObj
# console.log(alex === alexChanged); // -> false  // because they don't point to the same object in memory

# %% [markdown]
# ## TYPE COERCION

# %% [markdown]
# Is the attemp of Javascript to coerce or force one type into another type, (such as string to number, object to boolean, and so on)

# %%
# %%js
# console.log(25+true) // 26 - JS coerce true value to an One, false to a zero

# %% [markdown]
# ### Implicit vs. explicit coercion

# %% [markdown]
# *   When a developer expresses the intention to convert between types by writing the appropriate code, like Number(value), it’s called **explicit type coercion** (or type casting).
# *   **implicit type coercion** usually happens when you apply operators to values of different types, like
# 1 == null, 2/’5', null + new Date(), or it can be triggered by the surrounding context, like with if (value) {…}, where value is coerced to boolean.

# %%
# %%js
# String(123) // explicit
# 123 + ''    // implicit
# console.log(Number('123') )  // explicit
# console.log(+'123'       )   // implicit
# console.log(123 != '456')    // implicit
# console.log(4 > '5'    )     // implicit
# console.log(5/null    )   //infinity   // implicit
# console.log(true | 0 )    //1   // implicit

# %% [markdown]
# ### With operators

# %% [markdown]
# operators like -, *, / and %  will convert to numbers. PLUS not because it can be used to concatenate also.

# %%
# %%js
# console.log(25*false) //0
# console.log(5-"1") // 4
# console.log(5+"1") //51 - concatenates
#
# //concatenation all through
# console.log(1 + "2" + 1) // "121"

# %% [markdown]
# ### With Objects

# %% [markdown]
# Every javascript Object inherits a toString method, that is called whenever an Object is to be converted to a string. The return value of the toString method is used for such operations as string concatenation and mathematical expressions.

# %%
# %%js
# const foo = {}
# foo.toString() // [object Object]
#
# const baz = {
#   toString: () => "I'm object baz"
# }
#
# baz + "!" // "I'm object baz!"
#
# const foos = {
#   toString: () => 4
# }
#
# 2 * foos // 8

# %% [markdown]
# ### With arrays

# %%
# %%js
# [1,2,3].toString() // "1,2,3" //inherited toString() method
# [1,2,3].join() // "1,2,3" //toString works similar a join array's method
# [].toString() // ""
# [].join() // ""
#
# "me" + [1,2,3] // "me1,2,3"
# 4 + [1,2,3] // "41,2,3"
# 4 * [1,2,3] // NaN
#
# 4 * [] // 0
# 4 / [2] // 2

# %% [markdown]
# ### With true, false and ""

# %%
# %%js
# Number(true) // 1
# Number(false) // 0
# Number("") // 0
#
# 4 + true // 5
# 3 * false // 0
# 3 * "" // 0
# 3 + "" // "3"

# %% [markdown]
# ### Falsy and Truthy

# %% [markdown]
# in Javascript that return falsy values, they are:
#
#     * false
#     * 0
#     * null
#     * undefined
#     * ""
#     * NaN
#     * -0
#
# Everything else is truthy

# %%
# %%js
# if (-1) // truthy
# if ("0") // truthy
# if({}){ //truthy
#   console.log("hola")
# }
# if([]){ //thruty
#   console.log("holis")
# }

# %% [markdown]
# ### NaN

# %% [markdown]
# NaN is a special numeric value that is not equal to itself.

# %%
# %%js
# console.log(NaN === NaN) //false
# console.log(NaN == NaN) //false

# %% [markdown]
# ## DOM -> DOCUMENT OBJECT MODEL

# %% [markdown]
# The DOM (Document Object Model) is an API that represents and interacts with any HTML or XML document. The DOM is a document model loaded in the browser and representing the document as a node tree, where each node represents part of the document (e.g. an element, text string, or comment).
#
# The DOM is one of the most-used APIs on the Web because it allows code running in a browser to access and interact with every node in the document. Nodes can be created, moved and changed. Event listeners can be added to nodes and triggered on occurrence of a given event

# %% [markdown]
# ## PROMISES

# %% [markdown]
# A Promise is an object representing the eventual completion or failure of an asynchronous operation.
# `Promise.resolve()` and `Promise.reject()` are shortcuts to manually create an already resolved or rejected promise respectively. This can be useful at times.
# A promise can be:
# * fulfilled - The action relating to the promise succeeded
# * rejected - The action relating to the promise failed
# * pending - Hasn't fulfilled or rejected yet
# * settled - Has fulfilled or rejected
#
# It can be chained to another promise with `then` method

# %% [markdown]
# ## OBJECTS COPY

# %% [markdown]
# ### Shallow copy

# %% [markdown]
# ### Using ...spread operator

# %%
# %%js
# const food = { beef: '🥩', bacon: '🥓' };
#
# const cloneFood = { ...food };  //creates a new object
#
# console.log(cloneFood);
# cloneFood.cheese = '💌'
# console.log(cloneFood)
# console.log(food)

# %% [markdown]
# #### Using Object.assing

# %%
# %%js
# const food = { beef: '🥩', bacon: '🥓' };
#
# const cloneFood = Object.assign({}, food); // {} it's to not mutate the original
#
# console.log(cloneFood);
# // { beef: '🥩', bacon: '🥓' }

# %% [markdown]
# ### Deep copy

# %% [markdown]
# #### Using JSON

# %%
# %%js
# const food = { beef: '🥩', bacon: '🥓' };
#
# const cloneFood = JSON.parse(JSON.stringify(food));
#
# console.log(cloneFood);
# // { beef: '🥩', bacon: '🥓' }

# %% [markdown]
# #### Using lodash or builiding an algoritm

# %%
# %%js
# function deepEqual(object1, object2) {
#   const keys1 = Object.keys(object1);
#   const keys2 = Object.keys(object2);
#   if (keys1.length !== keys2.length) {
#     return false;
#   }
#   for (const key of keys1) {
#     const val1 = object1[key];
#     const val2 = object2[key];
#     const areObjects = isObject(val1) && isObject(val2);
#     if (
#       areObjects && !deepEqual(val1, val2) ||
#       !areObjects && val1 !== val2
#     ) {
#       return false;
#     }
#   }
#   return true;
# }
# function isObject(object) {
#   return object != null && typeof object === 'object';
# }
#
# const hero1 = {
#   name: 'Batman',
#   realName: 'Bruce Wayne'
# };
# const hero2 = {
#   name: 'Catwoman',
#   realName: 'Bruce Wayne',
#     address: {
#     city: 'Gotham'
#   }
# };
#
# console.log(deepEqual(hero1, hero2))

# %% [markdown]
# ##PROTOTYPE

# %% [markdown]
# Prototypes are the mechanism by which JavaScript objects inherit features from one another. JavaScript objects have a link to a prototype object.

# %% [markdown]
# ### Setting a prototype

# %% [markdown]
# #### Using Object.create

# %%
# %%js
# const personPrototype = {
#   greet() {
#     console.log('hello!');
#   }
# }
#
# const carl = Object.create(personPrototype);
# carl.greet();  // hello!

# %% [markdown]
# #### Using a constructor

# %%
# %%js
# const personPrototype = {
#   greet() {
#     console.log(`hello, my name is ${this.name}!`);
#   }
# }
#
# function Person(name) {
#   this.name = name;
# }
#
# Person.prototype = personPrototype;
# Person.prototype.constructor = Person;

# %% [markdown]
# ## INHERITANCE

# %% [markdown]
# When it comes to inheritance, JavaScript only has one construct: objects. Each object has a private property which holds a link to another object called its prototype. That prototype object has a prototype of its own, and so on until an object is reached with null as its prototype. By definition, null has no prototype, and acts as the final link in this prototype chain.
# When an inherited function is executed, the value of this points to the inheriting object, not to the prototype object where the function is an own property.
#
# We use the `extends` keyword to say that this class inherits from another class.

# %% [markdown]
# ## POSSIBLE INTERVIEW TOPICS

# %%
# %%js
# //VALUES VS REFERENCES ASSIGNMENTS
# var a = 5;
# var b = a;
# a = 7;
# console.log(a)
# console.log(b)
#
# var arr = [1];
# var arr2 = arr;
# arr.push(4)
# console.log(arr, arr2)
#
# //CURRYING
# function add(x){
#    return function(y){
#         return x + y;
#    }
# }
# console.log(add(3)(4)) // returns 7
#
# //REMOVING REPEATED ELEMENTS OF AN ARRAY
# let chars = ['A', 'B', 'A', 'C', 'B'];
#
# let uniqueChars = []
# chars.forEach(element =>{
#   if(!uniqueChars.includes(element)){
#     uniqueChars.push(element)
#   }
# })
# console.log(uniqueChars)
#
# // CALL METHOD (THIS)
# const person1 = {
#    firstName: 'Mark',
#    lastName: 'Manson',
#    fullName: function(){
#      console.log(this.firstName + ' ' + this.lastName)
#       return this.firstName + this.lastName
#    }
# }
# const person2 = {
#    firstName: 'Jason',
#    lastName: 'Mendes'
# }
# person1.fullName.call(person2) //person2 is the context or this to the fullName function

# %% [markdown]
# ##ADVANTAGES AND DISADVANTAGES OF JAVASCRIPT

# %% [markdown]
# # REACT

# %% [markdown]
# # HTML

# %% [markdown]
# ##DOCTYPE HTML  -> HTML HIPERTEXT MARKUP LANGUAGE

# %% [markdown]
# The HTML document type declaration, also known as DOCTYPE, is the first line of code required in every HTML or XHTML document. The DOCTYPE declaration is an instruction to the web browser about what version of HTML the page is written in. This ensures that the web page is parsed the same way by different web browsers.

# %% [markdown]
# ## TAGS INTRODUCED IN HTML5

# %% [markdown]
# ```
# <nav>: navigation
# <header>: set a group of content with a title
# <footer>: can contain information about the autor, copyright,etc
# <article>: big piece of content like blog entry of newspaper article
# <aside>: a piece of content that is slightly related the rest
# <figure>
# <audio>: file audio
# <section>: aplication section
# <time>: time and/ore date
# ```

# %% [markdown]
# ##SEMANTIC ELEMENTS

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Describes its meaning to both the browser and the developer:
#
#     <article>
#     <aside>
#     <details>
#     <figcaption>
#     <figure>
#     <footer>
#     <header>
#     <main>
#     <mark>
#     <nav>
#     <section>
#     <summary>
#     <time>

# %% [markdown]
# ## NON SEMANTIC ELEMENTS

# %% [markdown]
# `<div> and <span>` - Tells nothing about its content.

# %% [markdown]
# ##ACCESIBILITY (A11Y)

# %% [markdown]
# Accessibility is the practice of making your websites usable by as many people as possible. We traditionally think of this as being about people with disabilities, but the practice of making sites accessible also benefits other groups such as those using mobile devices, or those with slow network connections.
# * The accessibility tree is what most assistive technologies interact with

# %% [markdown]
# ### Benefits

# %% [markdown]
# * Semantic HTML, which improves accessibility, also improves SEO, making your site more findable.
# * Caring about accessibility demonstrates good ethics and morals, which improves your public image.
# * Other good practices that improve accessibility also make your site more usable by other groups, such as mobile phone users or those on low network speed. In fact, everyone can benefit from many such improvements.
# * It is mandatory in some countries

# %% [markdown]
# ### WAI-ARIA

# %% [markdown]
# **WAI-ARIA (Web Accessibility Initiative - Accessible Rich Internet Applications)**
# is a specification written by the W3C, defining a set of additional HTML attributes that can be applied to elements to provide additional semantics and improve accessibility wherever it is lacking. There are three main features defined in the spec:
# * **Roles** — These define what an element is or does. Many of these are so-called landmark roles, which largely duplicate the semantic value of HTML5 structural elements e.g. `role="navigation`" (<nav>) or `role="complementary"` (<aside>), `role="banner"`, `role="search"`, `role="tablist"`, `role="tab"`,
# * **Properties** — These define properties of elements, which can be used to give them extra meaning or semantics.
# `aria-required="true"` specifies that a form input needs to be filled in order to be valid, whereas `aria-labelledby="label"` allows you to put an ID on an element, then reference it.
# * **States**: — Special properties that define the current conditions of elements, such as `aria-disabled="true"`, which specifies to a screenreader that a form input is currently disabled.

# %% [markdown]
# ##SEO

# %% [markdown]
# **SEO (Search Engine Optimization)**.
# The process of making your site better for search engines.  Improving the quality and quantity of website traffic to a website or a web page from search engines.
# * Indexation:  Indexes contain the information on all the websites that Google (or any other search engine) was able to find. If a website is not in a search engine’s index, users will not be able to find it

# %% [markdown]
# ### Meta tags

# %%
<head>
  <meta charset="UTF-8">
  <meta name="description" content="Free Web tutorials">
  <meta name="keywords" content="HTML, CSS, JavaScript">
  <meta name="author" content="John Doe">
  <meta name="viewport" content="width=device-width, initial-scale=1.0">
</head>

# %% [markdown]
# Meta tags are essentially little content descriptors that help tell search engines what a web page is about.
# Some Tags:
# * `<title>`  most important to SEO
# * `<meta name="description">` little description about the page
# * `<meta name="viewport">` sets the visible area of a webpage
# * `<meta charset="UTF-8">` sets the character encoding for the web page. Most used: *UTF-8* - Character encoding for Unicode; *ISO-8859-1*- Character encoding for the Latin alphabet.

# %% [markdown]
# #VUE

# %% [markdown]
# is a JavaScript framework for building user interfaces. It builds on top of standard HTML, CSS and JavaScript, and provides a declarative and component-based programming model that helps you efficiently develop user interfaces, be it simple or complex.
#
# two core features of Vue:
# * Declarative Rendering: Vue extends standard HTML with a template syntax that allows us to declaratively describe HTML output based on JavaScript state.
#
# * Reactivity: Vue automatically tracks JavaScript state changes and efficiently updates the DOM when changes happen.

# %% [markdown]
# ## Virtual DOM

# %% [markdown]
# The virtual DOM (VDOM) is a programming concept where an ideal, or “virtual”, representation of a UI is kept in memory and synced with the “real” DOM.

# %% [markdown]
# ### Render pipeline

# %% [markdown]
# * **Compile**: Vue templates are compiled into render functions: functions that return virtual DOM trees. This step can be done either ahead-of-time via a build step, or on-the-fly by using the runtime compiler.
#
# * **Mount**: The runtime renderer invokes the render functions, walks the returned virtual DOM tree, and creates actual DOM nodes based on it. This step is performed as a reactive effect, so it keeps track of all reactive dependencies that were used.
#
# * **Patch**: When a dependency used during mount changes, the effect re-runs. This time, a new, updated Virtual DOM tree is created. The runtime renderer walks the new tree, compares it with the old one, and applies necessary updates to the actual DOM.

# %% [markdown]
# ## Two ways data binding

# %% [markdown]
# Two way data binding means that UI fields are bound to model data dynamically such that when a UI field changes, the model data changes with it and vice-versa.
# In vue:
# You can use the **v-model** directive to create **two-way data bindings** on form input, textarea, and select elements. It automatically picks the correct way to update the element based on the input type. Although a bit magical, v-model is essentially syntax sugar for updating data on user input events, plus special care for some edge cases.

# %% [markdown]
# ### created and mounted differences

# %% [markdown]
# created() : since the processing of the options is finished you have access to reactive data properties and change them if you want. At this stage DOM has not been mounted or added yet. So **you cannot do any DOM manipulation here**
#
# mounted(): called after the DOM has been mounted or rendered. Here you have access to the DOM elements and **DOM manipulation can be performed** for example get the innerHTML:

# %% [markdown]
# ## Concept of prop drilling

# %% [markdown]
# Is an anti-pattern of passing down props from paren components to it descendants via props, affecting a lot of components in order to get the child component desired. In Vue, we can solve prop drilling with provide and inject. Parent component -> provide, child component -> inject

# %% [markdown]
# #CLEAN CODE PRACTICES

# %% [markdown]
# * Create Meaningful Names
# * Use Pronounceable Names
# * Use Searchable Names
# * Write functions that do one thing
# * Don't repeate code
# * Don't leave code in comments
# * Keep function parameter count to a minimum

# %% [markdown]
# # REST API

# %% [markdown]
# is an application programming interface (API or web API) that conforms to the constraints of REST architectural style and allows for interaction with RESTful web services. REST stands for representational state transfer .
# When a client request is made via a RESTful API, it transfers a representation of the state of the resource to the requester or endpoint. This information, or representation, is delivered in one of several formats via HTTP: JSON (Javascript Object Notation), HTML, XLT, Python, PHP, or plain text.
# Something else to keep in mind: Headers and parameters are also important in the HTTP methods of a RESTful API HTTP request, as they contain important identifier information as to the request's metadata, authorization, uniform resource identifier (URI), caching, cookies, and more. There are request headers and response headers, each with their own HTTP connection information and status codes.

# %% [markdown]
# * Advantages:
#    * Updates
#    * Simplicity
#    * Popularity
#    * Speed
# * Disadvantages:
#   * Client-side security
#   * Browser support

# %% [markdown]
# principles keys dry solid
# design patterns singleton builder factory

# %% [markdown]
# #QUESTIONS INTERVIEW 6/05/22
# - Vue is two way data binding or one way data binding?
# - Filters in vue.js, make an example
# - delete reapeted numbers in an array using normal for [1,2,4,4,5,5,3]
# - difference between inline and block propertys CSS
# - max-width, min-width css
# - position absolute, what does it?
